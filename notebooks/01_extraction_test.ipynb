# %%
from src.parser import extract_requirements_json
requirement_text = """
Ik wil dat alle deuren van serverruimten en directiekantoren beveiligd worden met een IN kaartlezer
de directiekantoren moeten ook geopend kunnen worden met pincodes
Ik wil dat alle buitendeuren in en uit kaartlezers hebben, alle andere deuren krijgen alleen IN kaartlezers.
de serverruimte moet een gezichtscanner krijgen, ipv een kaartlezer, ook mogen deze tussen 9 en 5 geopend worden via een pincode
alleen de binnendeuren moeten voorzien worden van deurdrangers.
graag kloksysteem plaatsen bij de entree
ik wil alle buitendeuren motorsloten geven, en alle binnendeuren krijgen sluitplaten, behalve de serverruimte, deze krijgt een deurvasthoudmagneet
"""

# %%
from pathlib import Path
from src.parser import extract_requirements_json

print(requirement_text)
result = extract_requirements_json(requirement_text)
print(result)
# Out:
# Ik wil dat alle deuren van serverruimten en directiekantoren beveiligd worden met een IN kaartlezer
# de directiekantoren moeten ook geopend kunnen worden met pincodes
# Ik wil dat alle buitendeuren in en uit kaartlezers hebben, alle andere deuren krijgen alleen IN kaartlezers.
# de serverruimte moet een gezichtscanner krijgen, ipv een kaartlezer, ook mogen deze tussen 9 en 5 geopend worden via een pincode
# alleen de binnendeuren moeten voorzien worden van deurdrangers.
# graag kloksysteem plaatsen bij de entree
# ik wil alle buitendeuren motorsloten geven, en alle binnendeuren krijgen sluitplaten, behalve de serverruimte, deze krijgt een deurvasthoudmagneet
#
# {
#   "system_type": "ACCESS_CONTROL",
#   "version": "1.0",
#   "requirements": {
#     "door_rules": [
#       {
#         "areas": ["serverruimten"],
#         "reader_direction": "IN_ONLY",
#         "reader_types": ["FACE_RECOGNITION", "CODE"],
#         "lock_type": "MAGNETIC_LOCK",
#         "door_closer": "NONE",
#         "door_sensor": null,
#         "exit_device": null,
#         "emergency_button": null,
#         "anti_passback": null,
#         "description": "Serverruimten krijgen een IN gezichtsherkenning en kunnen worden geopend met pincode; slot is deurvasthoudmagneet"
#       },
#       {
#         "areas": ["directiekantoren"],
#         "reader_direction": "IN_ONLY",
#         "reader_types": ["CARD", "CODE"],
#         "lock_type": "ELECTRIC_STRIKE_PLATE",
#         "door_closer": "MECHANICAL",
#         "door_sensor": null,
#         "exit_device": null,
#         "emergency_button": null,
#         "anti_passback": null,
#         "description": "Directiekantoren krijgen een IN kaartlezer en kunnen worden geopend met pincode; slot is sluitplaat; deuren hebben deurdranger"
#       },
#       {
#         "areas": ["buitendeuren"],
#         "reader_direction": "IN_OUT",
#         "reader_types": ["CARD"],
#         "lock_type": "MOTORIZED_LOCK",
#         "door_closer": null,
#         "door_sensor": null,
#         "exit_device": null,
#         "emergency_button": null,
#         "anti_passback": null,
#         "description": "Buitendeuren krijgen IN/UIT kaartlezers en motorsloten"
#       },
#       {
#         "areas": ["overige binnendeuren"],
#         "reader_direction": "IN_ONLY",
#         "reader_types": ["CARD"],
#         "lock_type": "ELECTRIC_STRIKE_PLATE",
#         "door_closer": "MECHANICAL",
#         "door_sensor": null,
#         "exit_device": null,
#         "emergency_button": null,
#         "anti_passback": null,
#         "description": "Overige binnendeuren krijgen IN kaartlezers, sluitplaten en deurdranger"
#       }
#     ],
#     "controller_rules": []
#   }
# }
